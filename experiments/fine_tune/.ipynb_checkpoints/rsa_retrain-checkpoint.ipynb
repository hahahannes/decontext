# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import os 
os.environ['DATA_DIR'] = '/home/hhansen/decon/decon_env/DecontextEmbeddings/data'
os.environ['EMBEDDING_EVALUATION_DATA_PATH'] = '/home/hhansen/decon/decon_env/DecontextEmbeddings/embedding_evaluation/data/'

from scipy.stats import spearmanr, pearsonr
from scipy.spatial.distance import squareform
import numpy as np 
from collections import defaultdict

import os 
import sys 
sys.path.append('../..')

from helpers.things_evaluation.evaluate import evaluate
from helpers.plot import set_style_and_font_size
set_style_and_font_size()
# Out:
# /home/hhansen/decon/decon_env/DecontextEmbeddings/data

# %%
matching = 'word'
results = defaultdict(lambda: defaultdict(list))

test_words = list(pd.read_csv('../fine_tune/test_words.txt', header=None, names=['words'])['words'])
train_words = list(pd.read_csv('../fine_tune/train_words.txt', header=None, names=['words'])['words'])
val_words = list(pd.read_csv('../fine_tune/val_words.txt', header=None, names=['words'])['words'])

for mode, words in [('Train', train_words), ('Validation', val_words), ('Test', test_words)]:
    for file_name in ['mse_new', 'constrastive_loss', 'mse_loss']:
        for layer in range(13):
            path = f'../../../data_fine_tune/things/wikidumps/decontext/bert-base/{str(layer)}/{matching}/mean/all/{file_name}.txt'
            pearson, spearman, matrix, vec= evaluate(path, matching=matching, matching_words=words)
            results[mode][file_name].append(spearman.correlation)
# Out:
# Index(['abacus', 'air_conditioner', 'airboat', 'aloe', 'aluminum_foil',
#        'ambulance', 'amplifier', 'anchor', 'ankle', 'antelope',
#        ...
#        'windsock', 'wine_cooler', 'wire_cutters', 'wood', 'workbench', 'worm',
#        'wrap', 'yak', 'yolk', 'zucchini'],
#       dtype='object', name='things_id', length=501)
# Index(['abacus', 'air_conditioner', 'airboat', 'aloe', 'aluminum_foil',
#        'ambulance', 'amplifier', 'anchor', 'ankle', 'antelope',
#        ...
#        'windsock', 'wine_cooler', 'wire_cutters', 'wood', 'workbench', 'worm',
#        'wrap', 'yak', 'yolk', 'zucchini'],
#       dtype='object', name='things_id', length=501)
# Index(['abacus', 'air_conditioner', 'airboat', 'aloe', 'aluminum_foil',
#        'ambulance', 'amplifier', 'anchor', 'ankle', 'antelope',
#        ...
#        'windsock', 'wine_cooler', 'wire_cutters', 'wood', 'workbench', 'worm',
#        'wrap', 'yak', 'yolk', 'zucchini'],
#       dtype='object', name='things_id', length=501)
# ...

# %%
layers = range(13)

fig, axes = plt.subplots(1,2, figsize=(11,6), sharey=True)

combs = ['Train', 'Validation']

for i, mode in enumerate(combs):
    #axes[i].plot(layers, results[mode]['decontext'], label='without retraining')
    axes[i].plot(layers, results[mode]['mse_loss'], label='retraining with MSE')
    axes[i].plot(layers, results[mode]['constrastive_loss'], label='retraining with CL (classic)')
    axes[i].plot(layers, results[mode]['mse_new'], label='retraining with CL (weight decay)')

    axes[i].set_title(mode)


axes[0].set_ylabel('Spearman correlation')
axes[0].set_xlabel('Extraction layer')
axes[0].legend()
plt.tight_layout()
plt.savefig('finetune_test_correlation.pdf', bbox_inches='tight')
