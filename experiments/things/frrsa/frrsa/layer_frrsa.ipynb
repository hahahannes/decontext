# %%
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import sys 
sys.path.append('/home/hhansen/decon/decon_env/DecontextEmbeddings')
import os 
EMBEDDING_DATA_DIR = '/home/hhansen/decon/decon_env/data'
os.environ['EMBEDDING_DATA_DIR'] = EMBEDDING_DATA_DIR
os.environ['EMBEDDING_EVALUATION_DATA_PATH'] = '/home/hhansen/decon/decon_env/DecontextEmbeddings/helpers/embedding_evaluation/data/'
DATA_DIR = '/home/hhansen/decon/decon_env/DecontextEmbeddings/data'
os.environ['DATA_DIR'] = DATA_DIR


from helpers.embedding_evaluation.evaluate import Evaluation as wordsim_evaluate
from helpers.things_evaluation.evaluate import read_embeddings, load_behav, load_sorting, match_behv_sim, evaluate as run_evaluation
from helpers.data import yield_static_data
from helpers.intersection import get_intersection_words
from helpers.plot import get_ax
from helpers.data import load_spose_dimensions


from scipy.stats import spearmanr, pearsonr
from collections import defaultdict
import os 
from scipy.spatial.distance import squareform
from sklearn.linear_model import ElasticNetCV, MultiTaskElasticNetCV, RidgeCV, LassoCV, LinearRegression
from sklearn.model_selection import KFold, RepeatedKFold
from scipy.stats import spearmanr, pearsonr

from sklearn.preprocessing import StandardScaler

# %%
with open(f'spose_similarity.pkl', 'rb') as r_file:
    spose_similarity = pickle.load(r_file)
spose_similarity = squareform(spose_similarity, force='tovector', checks=False)
spose_similarity.shape
# Out:
# (360825,)

# %% [markdown]
# # Prepare FRRSA layer results

# %%
matching = 'main_word'
frrsa_sim_matrix_per_layer = defaultdict(list)

with open(f'frrsa_results_{matching}.pkl', 'rb') as r_file:
    results_frrsa = pickle.load(r_file)
    for model, _ in results_frrsa.items():
        if model != 'w2v' and model != 'glove':
            for layer in _:
                sim_matrix = layer[1][:, :, 0]
                sim_vector = squareform(sim_matrix, force='tovector', checks=False)
                frrsa_sim_matrix_per_layer[model].append(sim_vector)

# %%
for model in frrsa_sim_matrix_per_layer:
    df = pd.DataFrame(np.asarray(frrsa_sim_matrix_per_layer[model]).T)
    df['spose_similarity'] = spose_similarity
    df = df[~df.isin([9999]).any(axis=1)]
    frrsa_sim_matrix_per_layer[model] = df

# %%
frrsa_sim_matrix_per_layer['bert-base'].shape
# Out:
# (963, 14)

# %%
b = pd.DataFrame({'a': [1,2], 'b': [3,4]})
b[b['a'].isin([2])]
b[b.isin([2])]
# Out:
#      a   b
# 0  NaN NaN
# 1  2.0 NaN

# %% [markdown]
# # Mean baseline average

# %%
for model, result in frrsa_sim_matrix_per_layer.items():
    filtered_spose_similarity = result['spose_similarity']
    n_samples = filtered_spose_similarity.shape[0]
    mean_sim = result.iloc[:, :13].to_numpy().mean(axis=1)
    corr = pearsonr(filtered_spose_similarity, mean_sim)
    print(f'{model}: Pearsonr: {corr[0]} n_samples: {n_samples}')
# Out:
# bert-base: Pearsonr: 0.5140261802233548 n_samples: 963
# gpt-2: Pearsonr: 0.5545182855673332 n_samples: 968
# bert-large: Pearsonr: 0.20202278022732031 n_samples: 7
# gpt-2-medium: Pearsonr: -0.2335221864583686 n_samples: 8

# %% [markdown]
# # Regression based

# %%
def fit_model(layer_frrsa_similarity, spose_similarity, random_state):
    cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=random_state)
    ratios = [0.01, 0.1, 0.3, 0.5, 0.7, 0.9, 0.99]
    n_alphas = 10
    clf = ElasticNetCV(l1_ratio=ratios, n_alphas=n_alphas, fit_intercept=False, cv=cv, random_state=random_state)
    #clf = LinearRegression(fit_intercept=False)
    clf.fit(layer_frrsa_similarity, spose_similarity)
    return clf

# %%
def score(test_spose_similarity, pred_spose_similarity):
    return pearsonr(test_spose_similarity, pred_spose_similarity)[0]

# %%
def fit_and_score_regression(layer_frrsa_sim, spose_similarity):
    print(f'Predictor shape: {layer_frrsa_sim.shape} Target shape: {spose_similarity.shape}')
    outer_cv = RepeatedKFold(n_splits=5, n_repeats=5, random_state=42)
    n_samples = layer_frrsa_sim.shape[0]
    scores = []

    for i_split, (outer_train_ind, outer_test_ind) in enumerate(outer_cv.split(range(n_samples))):
        train_layer_frrsa_similarity = layer_frrsa_sim[outer_train_ind, :]
        #print(f'Number train samples: {train_layer_frrsa_similarity.shape[0]}')

        train_spose_similarity = spose_similarity[outer_train_ind]
        model = fit_model(train_layer_frrsa_similarity, train_spose_similarity, 42)

        test_spose_similarity = spose_similarity[outer_test_ind]
        test_frrsa_similarity = layer_frrsa_sim[outer_test_ind, :]
        #print(f'Number test samples: {test_frrsa_similarity.shape[0]}')

        pred_spose_similarity = model.predict(test_frrsa_similarity)
        pearson = score(test_spose_similarity, pred_spose_similarity)
        scores.append(pearson)
        
    return scores

# %%
for model, result in frrsa_sim_matrix_per_layer.items():
    #scaler = StandardScaler()
    spose_similarity = result.loc[:, 'spose_similarity'].to_numpy()
    result = result.drop(columns=['spose_similarity'])
    layer_frrsa_sim = result.to_numpy()
    #layer_frrsa_sim = scaler.fit_transform(layer_frrsa_sim)

    scores = fit_and_score_regression(layer_frrsa_sim, spose_similarity)
    cv_score = np.asarray(scores).mean()
    print(f'{model}: {cv_score}')
# Out:
# (963, 13) (963,)
# bert-base: 0.5455151120201068
# (968, 13) (968,)
# gpt-2: 0.6025194106882601
# (7, 25) (7,)
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.337e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.337e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.337e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.085e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.241e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.664e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.748e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.604e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.611e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.907e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.952e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.369e-05, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.646e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.965e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.812e-05, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.531e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.100e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.812e-05, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.531e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.100e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.085e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.241e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.664e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.611e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.907e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.952e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.369e-05, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.646e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.965e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.748e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.604e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.085e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.241e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.664e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.369e-05, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.646e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.965e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.812e-05, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.531e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.100e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.748e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.604e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.611e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.907e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.952e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.904e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.377e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.631e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.341e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.634e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.928e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.303e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.794e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.034e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.175e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.532e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.415e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.891e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.513e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.883e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.723e-05, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.513e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.883e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.723e-05, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.904e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.377e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.631e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.341e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.794e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.034e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.175e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.532e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.415e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.891e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.634e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.928e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.303e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.904e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.377e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.631e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.341e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.532e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.415e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.891e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.513e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.883e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.723e-05, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.634e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.928e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.303e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.794e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.034e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.175e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.481e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.606e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.890e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.994e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.093e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.024e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.062e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.129e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.556e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.843e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.288e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.656e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.457e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.065e-05, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.656e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.457e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.065e-05, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.481e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.606e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.890e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.062e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.129e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.556e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.843e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.288e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.994e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.093e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.024e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.481e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.606e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.890e-04, tolerance: 7.308e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.556e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.843e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.288e-04, tolerance: 6.852e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.656e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.457e-04, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.065e-05, tolerance: 5.225e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.994e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.093e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.024e-04, tolerance: 4.670e-05
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.159e-05, tolerance: 6.881e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.061e-04, tolerance: 1.055e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.009e-04, tolerance: 9.644e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.127e-05, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.068e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.131e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.474e-05, tolerance: 8.016e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.891e-04, tolerance: 8.016e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.844e-04, tolerance: 8.016e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.178e-04, tolerance: 7.926e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.226e-05, tolerance: 7.419e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.338e-04, tolerance: 7.419e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.127e-05, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.068e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.131e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.009e-04, tolerance: 9.644e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.161e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.308e-04, tolerance: 7.330e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.098e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.517e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.070e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.078e-04, tolerance: 9.644e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.171e-04, tolerance: 9.644e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.784e-05, tolerance: 8.016e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.321e-04, tolerance: 1.010e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.562e-04, tolerance: 1.010e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.078e-04, tolerance: 9.644e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.171e-04, tolerance: 9.644e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.098e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.517e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.070e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.784e-05, tolerance: 8.016e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.721e-04, tolerance: 7.926e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.321e-04, tolerance: 1.010e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.562e-04, tolerance: 1.010e-04
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.098e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.517e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.070e-04, tolerance: 7.461e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.078e-04, tolerance: 9.644e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.171e-04, tolerance: 9.644e-05
#   model = cd_fast.enet_coordinate_descent(
# /home/hhansen/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.711e-03, tolerance: 1.064e-04
#   model = cd_fast.enet_coordinate_descent(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-8a9764eeb0d2> in <module>
#       6     #layer_frrsa_sim = scaler.fit_transform(layer_frrsa_sim)
#       7
# ----> 8     scores = fit_and_score_regression(layer_frrsa_sim, spose_similarity)
#       9     cv_score = np.asarray(scores).mean()
#      10     print(f'{model}: {cv_score}')
#
# <ipython-input-60-07704fd0f4c4> in fit_and_score_regression(layer_frrsa_sim, spose_similarity)
#      17
#      18         pred_spose_similarity = model.predict(test_frrsa_similarity)
# ---> 19         pearson = score(test_spose_similarity, pred_spose_similarity)
#      20         scores.append(pearson)
#      21
#
# <ipython-input-59-0297a3934658> in score(test_spose_similarity, pred_spose_similarity)
#       1 def score(test_spose_similarity, pred_spose_similarity):
# ----> 2     return pearsonr(test_spose_similarity, pred_spose_similarity)[0]
#
# /SOFTWARE/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3836
#    3837     if n < 2:
# -> 3838         raise ValueError('x and y must have length at least 2.')
#    3839
#    3840     x = np.asarray(x)
#
# ValueError: x and y must have length at least 2.

# %%
df= frrsa_sim_matrix_per_layer['bert-base']
df
# Out:
#                0         1         2         3         4         5         6  \
# 1099    0.306237  0.273510  0.285984  0.284254  0.265938  0.255552  0.282335
# 3468    0.303125  0.222166  0.237801  0.238570  0.252180  0.198098  0.204494
# 3814    0.314255  0.335804  0.356492  0.341691  0.432666  0.467250  0.540340
# 3837    0.288585  0.293443  0.298734  0.293094  0.324815  0.318068  0.412525
# 3856    0.342099  0.353948  0.327357  0.342607  0.381556  0.286950  0.283015
# ...          ...       ...       ...       ...       ...       ...       ...
# 359761  0.301224  0.249336  0.241258  0.208347  0.214260  0.210785  0.236306
# 360011  0.342137  0.297560  0.295694  0.286483  0.265788  0.238111  0.258982
# 360178  0.345948  0.307158  0.347527  0.382970  0.431268  0.447351  0.472872
# 360407  0.302457  0.283571  0.324616  0.305253  0.366046  0.329993  0.315409
# 360456  0.351588  0.365371  0.386158  0.346891  0.375121  0.344272  0.313781
#
#                7         8         9        10        11        12  \
# 1099    0.271220  0.235269  0.212936  0.196851  0.204278  0.230541
# 3468    0.245597  0.230679  0.200986  0.178957  0.225390  0.277387
# 3814    0.509627  0.527027  0.591948  0.509716  0.450000  0.361018
# 3837    0.481433  0.529062  0.450301  0.415534  0.412009  0.376312
# 3856    0.376693  0.327220  0.341442  0.289354  0.300546  0.385862
# ...          ...       ...       ...       ...       ...       ...
# 359761  0.235901  0.172584  0.172250  0.231718  0.178078  0.234691
# 360011  0.250928  0.244811  0.221458  0.220769  0.283343  0.346612
# 360178  0.427386  0.469078  0.443052  0.432534  0.405102  0.478486
# 360407  0.323675  0.307080  0.274973  0.355095  0.361250  0.279596
# 360456  0.290859  0.270131  0.253140  0.290273  0.292460  0.330080
#
#         spose_similarity
# 1099            0.129707
# 3468            0.216209
# 3814            0.516748
# 3837            0.327900
# 3856            0.251489
# ...                  ...
# 359761          0.312069
# 360011          0.640844
# 360178          0.268397
# 360407          0.225815
# 360456          0.135814
#
# [963 rows x 14 columns]
