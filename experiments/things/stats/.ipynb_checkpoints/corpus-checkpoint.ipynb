# %%
import pandas as pd
import matplotlib.pyplot as plt


import os 
import sys 
sys.path.append('/home/hhansen/decon/decon_env/DecontextEmbeddings')
sys.path

DATA_DIR = '/home/hhansen/decon/decon_env/DecontextEmbeddings/data'
EMBEDDING_DATA_DIR = '/home/hhansen/decon/decon_env/data'

os.environ['DATA_DIR'] = DATA_DIR

from helpers.data import load_embedding_to_df
from helpers.things_evaluation.evaluate import read_embeddings
from helpers.plot import set_style_and_font_size

set_style_and_font_size()

os.environ['EMBEDDING_EVALUATION_DATA_PATH'] = '/home/hhansen/decon/decon_env/DecontextEmbeddings/helpers/embedding_evaluation/data/'

# %%
def missing_things(df):
    words = set(pd.read_csv(f'{DATA_DIR}/things/things_concepts.tsv', sep='\t')['uniqueID'])
    missing = words.difference(df.index)
    print(missing)
    print(f'{len(missing)} missing of {len(words)}')

def stats_things(corpus_folder):
    matchings = ['word', 'synset', 'main_word', 'concept_id']
    dfs = []
    for matching in matchings:
        print(f'Matching: {matching}')
        path = f'{EMBEDDING_DATA_DIR}/thinga/{corpus_folder}/decontext/bert-base/1/{matching}/mean/1/decontext.txt'
        df = read_embeddings(path, matching, keep_n_contexts=True)[['n_contexts']]
        df = df.sort_values(by='n_contexts', ascending=False)
        dfs.append(df)
        
        total = df['n_contexts'].sum()
        print(f'Total number of embeddings: {total}')
        print(f'{df.shape[0]} concepts found')
        #print(df['n_contexts'].describe())
        missing_things(df)

    return dfs

# %%
def plot_hist(df_word, df_synset, df_main_word, df_concept_id):
    fig, axes = plt.subplots(1,4, figsize=(10,3), sharey=True, sharex=True)
    axes[0].hist(df_word['n_contexts'], bins=200)
    axes[1].hist(df_synset['n_contexts'], bins=200)
    axes[2].hist(df_main_word['n_contexts'], bins=200)
    axes[3].hist(df_concept_id['n_contexts'], bins=200)
    axes[0].set_ylabel('number of words')
    axes[0].set_xlabel('number of contexts')
    axes[0].set_title('per word')
    axes[1].set_title('per word sense')
    axes[2].set_title('per concept')
    axes[3].set_title('per synset')

def plot_boxplot(df_word, df_synset, df_main_word, df_concept_id):
    fig, axes = plt.subplots(1,1, figsize=(11.69,5), sharey=True, sharex=True)
    axes.boxplot([df_word['n_contexts'], df_synset['n_contexts'], df_main_word['n_contexts'], df_concept_id['n_contexts']], vert=False)
    axes.set_yticks([1,2,3,4])
    axes.set_yticklabels(['word', 'word sense', 'concept', 'synset'])
    axes.set_xlabel('number of contexts')

# %%
df_word, df_synset, df_main_word, df_concept_id = stats_things('wikidumps')
# Out:
# Matching: word
# Total number of embeddings: 1607766
# 1852 concepts found
# {'ticktacktoe', 'iceskate'}
# 2 missing of 1854
# Matching: synset
# Total number of embeddings: 820555
# 1084 concepts found
# {'panther', 'hammer', 'truck', 'licorice', 'buggy', 'treasure', 'mulberry', 'pickle', 'brush', 'net', 'strap', 'clipper1', 'plunger', 'pipe1', 'mistletoe', 'pig', 'duck', 'bunkbed', 'nail', 'goblet', 'alligator', 'fly', 'plate', 'siren', 'shutter', 'grille', 'cat', 'trunk', 'firetruck', 'yak', 'powder', 'board', 'lion', 'roll', 'trough', 'hotdog', 'carrot', 'slug', 'finger', 'hamburger', 'snowball', 'goose', 'tablet', 'mustard', 'skunk', 'spider_web', 'steamroller', 'walker2', 'icemaker', 'garbage', 'suit', 'fingerprint', 'sombrero', 'button2', 'almond', 'yoke', 'punching_bag', 'saucer', 'toothbrush', 'light_switch', 'crank', 'foot', 'bow3', 'pole', 'horn', 'rickshaw', 'lobster', 'mint', 'swordfish', 'fence', 'batter', 'hobbyhorse', 'sprouts', 'mat', 'drain', 'kale', 'mail', 'stretcher', 'chip', 'canvas', 'blueberry', 'diamond', 'mannequin', 'file1', 'teabag', 'scallop', 'mole', 'float', 'stump', 'switch', 'earplug', 'bracelet1', 'gravel', 'bubble_wrap', 'eyedropper', 'chalk', 'chain', 'otter', 'globe', 'bread', 'brownie', 'pillbox', 'uniform', 'motorcycle', 'flatiron', 'sugar_cube', 'eye', 'whip', 'jug', 'folder', 'saffron', 'centerpiece', 'rack1', 'can', 'tee', 'leg', 'thread', 'ready_meal', 'frame', 'ostrich', 'van', 'jar', 'quill', 'retainer', 'pumpkin', 'ice', 'tweezers', 'loom', 'spinach', 'lettuce', 'calf2', 'satellite_dish', 'waterwheel', 'raspberry', 'chickpea', 'sidecar', 'trophy', 'saddle', 'whistle', 'whale', 'seal', 'dogfood', 'perfume', 'poster', 'sweet_potato', 'album', 'fork', 'gourd', 'charger', 'ticktacktoe', 'turban', 'belt', 'tent', 'drumstick', 'baton2', 'yarn', 'squid', 'puck', 'racket', 'crane', 'chisel', 'wheel', 'coaster', 'mug', 'cloud', 'ruler', 'game', 'rake', 'stamp2', 'rat', 'sand', 'plant', 'dolly', 'glove', 'marijuana', 'lemon', 'crayfish', 'taco', 'rattle', 'iron', 'pants', 'payphone', 'macaroni', 'skin', 'cable', 'scale', 'stool', 'lime', 'egg', 'riser', 'sandbag', 'tamale', 'screen2', 'sardine', 'keg', 'catfish', 'sweatsuit', 'mop', 'paddle', 'arrow', 'carousel', 'grinder', 'peanut', 'latch', 'man', 'javelin', 'fire', 'gem', 'wick', 'curb', 'funnel', 'revolving_door', 'puddle', 'blind', 'parachute', 'highlighter', 'shelf', 'wand', 'squash', 'vulture', 'closet', 'drink', 'popcorn', 'pipe2', 'fire_pit', 'router', 'camera2', 'whoopee_cushion', 'lamp', 'smoothie', 'hole', 'fuse', 'stirrup', 'cage', 'photo_booth', 'toilet', 'knot', 'snail', 'glass', 'shower', 'bamboo', 'spareribs', 'calzone', 'binder', 'robe', 'counter', 'sink', 'handprint', 'bologna', 'dip', 'scanner', 'goat', 'camper', 'pudding', 'computer', 'gargoyle', 'cordon_bleu', 'heater', 'duct', 'carriage', 'cake', 'nail_clippers', 'tie', 'toy', 'stem', 'shoe', 'mango', 'screw', 'torpedo', 'wire', 'shell3', 'file2', 'shell2', 'amber', 'pepper2', 'pom-pom', 'trapdoor', 'mixer', 'lanyard', 'sling', 'handbrake', 'splinter', 'tree', 'pea', 'wagon', 'wire_cutters', 'stove2', 'scrabble', 'projector', 'chicken2', 'trashcan', 'tape', 'pill', 'doghouse', 'rhinoceros', 'parsley', 'pedal', 'slot', 'duckling', 'ferret', 'grapevine', 'grass', 'pot', 'timer', 'coral', 'piano', 'gold', 'jersey', 'sweater', 'hood', 'dreidel', 'airbag', 'pomegranate', 'mallet', 'kiwi', 'chariot', 'chinchilla', 'railing', 'jack', 'pennant', 'shell1', 'celery', 'shaker', 'grate', 'coil', 'ski_boots', 'peppermint', 'raft', 'catapult', 'tab', 'bumper', 'noodle', 'map', 'dustpan', 'cork', 'cardinal', 'pajamas', 'patch', 'leaf', 'thimble', 'spaghetti', 'football', 'rifle', 'valve', 'dalmatian', 'column', 'punch2', 'crown', 'nut', 'duffel_bag', 'car', 'horseshoe', 'mold2', 'train_car', 'sloth', 'whiteboard', 'rope', 'marble', 'pocket', 'sheath', 'jacket', 'beet', 'ship', 'reel', 'chaps', 'toast', 'footrest', 'veil', 'boot', 'bush', 'coffeemaker', 'chihuahua', 'spoon', 'snow', 'clove', 'basketball', 'vent', 'outlet', 'clasp', 'lunchbox', 'lid', 'cord', 'rollerskate', 'lip_gloss', 'shield', 'rudder', 'hose', 'fossil', 'ear', 'mullet', 'nest', 'cranberry', 'plum', 'ratchet', 'beave ...
# 770 missing of 1854
# Matching: main_word
# Total number of embeddings: 1692244
# 1854 concepts found
# set()
# 0 missing of 1854
# Matching: concept_id
# Total number of embeddings: 803915
# 1017 concepts found
# {'bra', 'panther', 'golf_club', 'wheelbarrow', 'hammer', 'truck', 'licorice', 'buggy', 'treasure', 'mulberry', 'squirt_gun', 'beachball', 'pickle', 'brush', 'guardrail', 'strap', 'clipper1', 'sorbet', 'pipe1', 'iguana', 'mistletoe', 'pig', 'duck', 'bunkbed', 'eggshell', 'orange_rind', 'nail', 'trumpet', 'goblet', 'fly', 'plate', 'trolley', 'siren', 'shutter', 'grille', 'cat', 'trunk', 'firetruck', 'speaker', 'cd_player', 'yak', 'wooden_leg', 'board', 'lion', 'powder', 'roll', 'trough', 'carrot', 'slug', 'finger', 'hamburger', 'shrimp', 'snowball', 'tablet', 'goose', 'skunk', 'mustard', 'spider_web', 'walker2', 'cement_mixer', 'icemaker', 'garbage', 'suit', 'fingerprint', 'popsicle', 'button2', 'ping-pong_table', 'almond', 'lifesaver', 'yoke', 'punching_bag', 'saucer', 'gum', 'toothbrush', 'light_switch', 'crank', 'exerciser', 'bow3', 'pole', 'horn', 'cutting_board', 'rickshaw', 'lobster', 'mint', 'swordfish', 'fishing_pole', 'batter', 'stomach', 'hobbyhorse', 'donut', 'golf_cart', 'ukulele', 'sprouts', 'mat', 'chive', 'mail', 'stretcher', 'meatloaf', 'canvas', 'blueberry', 'frisbee', 'rooster', 'diamond', 'mannequin', 'file1', 'teabag', 'scallop', 'mole', 'float', 'stump', 'switch', 'earplug', 'bracelet1', 'velcro', 'possum', 'bubble_wrap', 'eyedropper', 'chalk', 'chain', 'otter', 'globe', 'scuba', 'filing_cabinet', 'brownie', 'pillbox', 'uniform', 'ferris_wheel', 'motorcycle', 'flatiron', 'pine_needle', 'sugar_cube', 'panda', 'whip', 'jug', 'folder', 'saffron', 'lightbulb', 'centerpiece', 'rack1', 'teepee', 'robot', 'can', 'tee', 'leg', 'thread', 'ready_meal', 'frame', 'ostrich', 'van', 'jar', 'magnifying_glass', 'quill', 'cellphone', 'retainer', 'pumpkin', 'ice', 'tweezers', 'loom', 'reindeer', 'spinach', 'lettuce', 'police_car', 'calf2', 'satellite_dish', 'waterwheel', 'raspberry', 'chickpea', 'sidecar', 'trophy', 'saddle', 'whistle', 'whale', 'dogfood', 'seal', 'perfume', 'poster', 'sweet_potato', 'album', 'wine_cooler', 'fork', 'gourd', 'charger', 'turban', 'belt', 'tent', 'drumstick', 'baton2', 'yarn', 'squid', 'crane', 'chisel', 'wheel', 'coaster', 'mug', 'cloud', 'stair', 'game', 'stamp2', 'rake', 'rat', 'petri_dish', 'sand', 'plant', 'dolly', 'glove', 'lemon', 'taco', 'rattle', 'iron', 'pants', 'payphone', 'coat_rack', 'macaroni', 'scale', 'extinguisher', 'stool', 'lime', 'riser', 'sandbag', 'screen2', 'sardine', 'keg', 'catfish', 'sweatsuit', 'dishwashing_liquid', 'mop', 'paddle', 'bowtie', 'arrow', 'carousel', 'grinder', 'peanut', 'latch', 'weather_vane', 'javelin', 'fire', 'pacifier', 'wick', 'funnel', 'revolving_door', 'polisher', 'puddle', 'cornucopia', 'parachute', 'highlighter', 'undershirt', 'shelf', 'wand', 'squash', 'vulture', 'closet', 'drink', 'popcorn', 'pipe2', 'fire_pit', 'camera2', 'lamp', 'router', 'whoopee_cushion', 'smoothie', 'hole', 'fuse', 'stirrup', 'photo_booth', 'knot', 'snail', 'glass', 'shower', 'plastic_film', 'bamboo', 'spareribs', 'calzone', 'robe', 'saxophone', 'counter', 'sink', 'donkey', 'handprint', 'dip', 'scanner', 'goat', 'pudding', 'gargoyle', 'cordon_bleu', 'duct', 'water_fountain', 'carriage', 'cake', 'nail_clippers', 'tie', 'toy', 'stem', 'shoe', 'french_horn', 'mango', 'screw', 'torpedo', 'wire', 'shell3', 'file2', 'shell2', 'top_hat', 'amber', 'pepper2', 'pom-pom', 'trapdoor', 'mixer', 'lanyard', 'handbrake', 'splinter', 'tree', 'pea', 'wagon', 'wire_cutters', 'stove2', 'scrabble', 'projector', 'videogame', 'trashcan', 'tape', 'candelabra', 'pill', 'doghouse', 'rhinoceros', 'parsley', 'slot', 'duckling', 'glasses', 'ferret', 'moose', 'grass', 'pot', 'timer', 'crepe', 'coral', 'gold', 'jersey', 'sweater', 'hood', 'dreidel', 'dirt_bike', 'laundry_basket', 'airbag', 'pomegranate', 'pickax', 'dresser', 'mallet', 'kiwi', 'chariot', 'chinchilla', 'railing', 'jack', 'pennant', 'shell1', 'celery', 'shaker', 'fire_hydrant', 'grate', 'flashbulb', 'coil', 'ski_boots', 'peppermint', 'raft', 'sofa_bed', 'tab', 'bumper', 'noodle', 'map', 'dustpan', 'cork', 'cardinal', 'patch', 'leaf', 'sea ...
# 837 missing of 1854

# %%
plot_hist(df_word, df_synset, df_main_word, df_concept_id)
plt.savefig(f'things_wikidumps_hist.pdf', bbox_inches='tight')

# %%
plot_boxplot(df_word, df_synset, df_main_word, df_concept_id)
plt.savefig(f'things_wikidumps_boxpot.pdf', bbox_inches='tight')
